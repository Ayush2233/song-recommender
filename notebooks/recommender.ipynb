# %%
import os
import pandas as pd

root_path = '../'

# Change the current working directory to the root path
os.chdir(root_path)
import utils.functions as f

# %%
# Title & artist input by user
user_input_title = 'Closer'
user_input_artist = ''

# %%
# Get spotify data including track_id
sp_song_data = f.search_song(user_input_title, user_input_artist)

# %%
sp_song_data
# Out:
# [{'result_index': 0,
#   'track_id': '7BKLCZ1jbUBVqRi2FVlTVw',
#   'href': 'https://api.spotify.com/v1/tracks/7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_link': 'https://open.spotify.com/track/7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_name': 'Closer',
#   'artist': 'The Chainsmokers',
#   'album_name': 'Closer',
#   'album_release_year': '2016-07-29',
#   'track_duration': 245,
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e02495ce6da9aeb159e94eaa453'},
#  {'result_index': 1,
#   'track_id': '3K4HG9evC7dg3N0R9cYqk4',
#   'href': 'https://api.spotify.com/v1/tracks/3K4HG9evC7dg3N0R9cYqk4',
#   'track_link': 'https://open.spotify.com/track/3K4HG9evC7dg3N0R9cYqk4',
#   'track_name': 'One Step Closer',
#   'artist': 'Linkin Park',
#   'album_name': 'Hybrid Theory (Bonus Edition)',
#   'album_release_year': '2000',
#   'track_duration': 157,
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e02e2f039481babe23658fc719a'},
#  {'result_index': 2,
#   'track_id': '2oDqmfa2g8W893LlwJG1qu',
#   'href': 'https://api.spotify.com/v1/tracks/2oDqmfa2g8W893LlwJG1qu',
#   'track_link': 'https://open.spotify.com/track/2oDqmfa2g8W893LlwJG1qu',
#   'track_name': 'Closer',
#   'artist': 'Nine Inch Nails',
#   'album_name': 'The Downward Spiral',
#   'album_release_year': '1994-03-08',
#   'track_duration': 373,
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e02f69bd9abbfeb819840993207'},
#  {'result_index': 3,
#   'track_id': '2XbfY2O2v3xwedUJ0J2kkr',
#   'href': 'https://api.spotify.com/v1/tracks/2XbfY2O2v3xwedUJ0J2kkr',
#   'track_link': 'https://open.spotify.com/track/2XbfY2O2v3xwedUJ0J2kkr',
#   'track_name': 'Closer',
#   'artist': 'Ne-Yo',
#   'album_name': 'Year Of The Gentleman (Bonus Track Edition)',
#   'album_release_year': '2008-01-01',
#   'track_duration': 234,
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e025694163d7c4ab48251e9b57c'},
#  {'result_index': 4,
#   'track_id': '4sebUbjqbcgDSwG6PbSGI0',
#   'href': 'https://api.spotify.com/v1/tracks/4sebUbjqbcgDSwG6PbSGI0',
#   'track_link': 'https://open.spotify.com/track/4sebUbjqbcgDSwG6PbSGI0',
#   'track_name': 'Come a Little Closer',
#   'artist': 'Cage The Elephant',
#   'album_name': 'Melophobia',
#   'album_release_year': '2013-10-08',
#   'track_duration': 229,
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e02fb1cb900d28642e668d77b12'}]

# %%
user_song_selection = 0
track_id = sp_song_data[user_song_selection]['track_id']

# %%
recommended_songs = f.recommend_song(track_id, 0, 100)

recommended_songs
# Out:
# Audio features download complete. Success rate: 100 %
# Succesful downloads: 1 Failed downloads: 0
#        Unnamed: 0                track_id            artists  \
# 13139       13139  4IafOiqRWk6W9zSe74llhg     Chez Damier;MK
# 94578       94578  3vzbNQi4mQ9tmvroysU2f3              Ollie
# 53031       53031  5IGsV7tGijVH9R7KtneqKn  Tiësto;Charli XCX
# 90963       90963  1Cls464Epr7JDUxwyEbQEg        Sonia Rivas
# 11791       11791  4KRgqwb4kvBuTz1utbYxfb        The Beatles
#
#                   album_name                                track_name  \
# 13139        Can You Feel It                  Can You Feel It - MK Dub
# 94578              Lost - EP                                      Lost
# 53031          Daily Pop Mix                                 Hot in It
# 90963            Sonia Rivas                  Amor No Te Guardo Rencor
# 11791  Revolver (Remastered)  And Your Bird Can Sing - Remastered 2009
#
#        popularity  duration_ms  explicit  danceability  energy  ...  mode  \
# 13139          16       296258     False         0.726   0.849  ...     1
# 94578          52       219580     False         0.801   0.545  ...     1
# 53031           0       129817     False         0.748   0.841  ...     1
# 90963          28       172706     False         0.701   0.548  ...     1
# 11791          57       120493     False         0.555   0.650  ...     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 13139       0.0384       0.00051          0.295000    0.2440    0.681
# 94578       0.0888       0.24800          0.000000    0.1360    0.269
# 53031       0.1770       0.00445          0.000001    0.0413    0.717
# 90963       0.0315       0.36700          0.000000    0.2350    0.842
# 11791       0.0282       0.00670          0.049100    0.2360    0.966
#
#          tempo  time_signature    track_genre  cluster
# 13139  130.241               4  chicago-house        1
# 94578  129.966               4            sad        1
# 53031  123.045               4          house        1
# 90963  119.938               4    rock-n-roll        1
# 11791  132.590               4        british        1
#
# [5 rows x 22 columns]

# %%
temp = f.searchbyid("4IafOiqRWk6W9zSe74llhg")

# %%
temp
# Out:
# []
